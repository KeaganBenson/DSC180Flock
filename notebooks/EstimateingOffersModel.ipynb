# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
pd.options.display.max_columns = 31

# %%
offers = pd.read_csv("offer_acceptance_offers.csv",low_memory=False)
orders = pd.read_csv('offer_acceptance_orders.csv',low_memory=False)

# %%
# variables used for modeling
bool_column_names = [
 'FD_ENABLED',
 'EXCLUSIVE_USE_REQUESTED',
 'HAZARDOUS',
 'REEFER_ALLOWED',
 'STRAIGHT_TRUCK_ALLOWED',
 'LOAD_TO_RIDE_REQUESTED',
]

numerical_loggable_column_names = [
 'APPROXIMATE_DRIVING_ROUTE_MILEAGE',
 'PALLETIZED_LINEAR_FEET',
 'SECONDS_BETWEEN_ORDER_AND_DEADLINE',
 'LOAD_BAR_COUNT',
 'ESTIMATED_COST_AT_ORDER'
]

# %% [markdown]
# # Data Cleaning

# %%
# dates -> DT & creating new time delta variable
orders['ORDER_DATETIME_PST'] = pd.to_datetime(orders['ORDER_DATETIME_PST'])
orders['PICKUP_DEADLINE_PST'] = pd.to_datetime(orders['PICKUP_DEADLINE_PST'])
offers['CREATED_ON_HQ'] = pd.to_datetime(offers['CREATED_ON_HQ'])
orders['Time_between_Order_pickup'] = (orders['PICKUP_DEADLINE_PST'] - 
                                                orders['ORDER_DATETIME_PST'])

# %%
# fill driving distance with mean of in zip code results, most na were in zip code
same = orders[orders['ORIGIN_3DIGIT_ZIP'] ==  orders['DESTINATION_3DIGIT_ZIP']]
mean_same_distance = same['APPROXIMATE_DRIVING_ROUTE_MILEAGE'].dropna().mean()
orders['APPROXIMATE_DRIVING_ROUTE_MILEAGE'] = orders['APPROXIMATE_DRIVING_ROUTE_MILEAGE'].fillna(mean_same_distance)

# fill FD enabled with false
orders['FD_ENABLED'] = orders['FD_ENABLED'].fillna(False)

# drop everything else, cause all had consistance NA 7
# 18 in Transportmode
# change all boolean data back to boolean
containsNa = (orders.isnull().sum() > 1).to_dict()
orders = orders.dropna()
for key,value in containsNa.items():
    if value:
        if orders[key].unique().sum() == 1:
            orders[key] = orders[key].astype(bool)

# %%
s = offers.groupby('REFERENCE_NUMBER').count()['CARRIER_ID']
nOffers_rec = s[s < 15]

# %%
ftl = orders[orders['TRANSPORT_MODE'] == 'FTL']
ftl.set_index('REFERENCE_NUMBER',inplace = True)
joinedDF = ftl.join(nOffers_rec,how = 'left')
joinedDF['NUMBER_OFFERS'] = joinedDF['CARRIER_ID'].fillna(0)
joinedDF.drop('CARRIER_ID',axis = 1,inplace = True)
joinedDF['SECONDS_BETWEEN_ORDER_AND_DEADLINE'] = joinedDF['Time_between_Order_pickup'].dt.total_seconds()

# %%
accept_offers = offers[offers['LOAD_DELIVERED_FROM_OFFER'] == True]

# %%
joined_oo = pd.merge(accept_offers, orders, how='inner')

# %%
joined_oo['LEAD_TIME'] =  joined_oo['PICKUP_DEADLINE_PST'] - joined_oo['CREATED_ON_HQ']

# %%
#joined table of both ftl/ptl offers that are accepeted, column LEAD_TIME is time between accpt offr and pickupdeadline
joined_oo['LEAD_TIME'].describe()
# Out:
# count                       126411
# mean     1 days 11:55:15.270799218
# std      3 days 02:23:02.503108674
# min            -149 days +19:24:32
# 25%         0 days 05:33:09.500000
# 50%                0 days 21:38:57
# 75%         1 days 19:42:24.500000
# max              365 days 07:07:41
# Name: LEAD_TIME, dtype: object

# %%
def bin_leadtime(df):
    if df['LEAD_TIME'] >= (df.quantile(q=0.75)['LEAD_TIME']).astype('dateime'):
        return 4
    elif df['LEAD_TIME'] >= (df.quantile(q=0.5)['LEAD_TIME']).astype('dateime'):
        return 3
    elif df['LEAD_TIME'] >= (df.quantile(q=0.25)['LEAD_TIME']).astype('dateime'):
        return 2
    return 1

# %%
joined_oo['LEADTIME_BIN'] = joined_oo.apply(bin_leadtime, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_101/980518113.py in <module>
# ----> 1 joined_oo['LEADTIME_BIN'] = joined_oo.apply(bin_leadtime, axis=1)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
#     859         # wrap results
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     871             for i, v in enumerate(series_gen):
#     872                 # ignore SettingWithCopy here in case the user mutates
# --> 873                 results[i] = self.f(v)
#     874                 if isinstance(results[i], ABCSeries):
#     875                     # If we have a view on v, we need to make a copy because
#
# /tmp/ipykernel_101/1250249522.py in bin_leadtime(df)
#       1 def bin_leadtime(df):
# ----> 2     if df['LEAD_TIME'] >= (df.quantile(q=0.75)['LEAD_TIME']).astype('dateime'):
#       3         return 4
#       4     elif df['LEAD_TIME'] >= (df.quantile(q=0.5)['LEAD_TIME']).astype('dateime'):
#       5         return 3
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/series.py in quantile(self, q, interpolation)
#    2495         df = self.to_frame()
#    2496
# -> 2497         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2498         if result.ndim == 2:
#    2499             result = result.iloc[:, 0]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation)
#   10491         if not is_list_like(q):
#   10492             # BlockManager.quantile expects listlike, so we wrap and unwrap here
# > 10493             res = self.quantile(
#   10494                 [q], axis=axis, numeric_only=numeric_only, interpolation=interpolation
#   10495             )
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation)
#   10510             return self._constructor_sliced([], index=cols, name=q, dtype=np.float64)
#   10511
# > 10512         res = data._mgr.quantile(qs=q, axis=1, interpolation=interpolation)
#   10513
#   10514         result = self._constructor(res)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/managers.py in quantile(self, qs, axis, interpolation)
#    1459         new_axes[1] = Float64Index(qs)
#    1460
# -> 1461         blocks = [
#    1462             blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1463             for blk in self.blocks
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1460
#    1461         blocks = [
# -> 1462             blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1463             for blk in self.blocks
#    1464         ]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/blocks.py in quantile(self, qs, interpolation, axis)
#    1343         assert is_list_like(qs)  # caller is responsible for this
#    1344
# -> 1345         result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1346         # ensure_block_shape needed for cases where we start with EA and result
#    1347         #  is ndarray, e.g. IntegerArray, SparseArray
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/array_algos/quantile.py in quantile_compat(values, qs, interpolation)
#      36         fill_value = na_value_for_dtype(values.dtype, compat=False)
#      37         mask = isna(values)
# ---> 38         return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      39     else:
#      40         return values._quantile(qs, interpolation)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/array_algos/quantile.py in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      86         result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      87     else:
# ---> 88         result = _nanpercentile(
#      89             values,
#      90             qs * 100.0,
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/array_algos/quantile.py in _nanpercentile(values, qs, na_value, mask, interpolation)
#     184         return result
#     185     else:
# --> 186         return np.percentile(
#     187             values, qs, axis=1, **{np_percentile_argname: interpolation}
#     188         )
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3730     if not _quantile_is_valid(q):
#    3731         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 3732     return _quantile_unchecked(
#    3733         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3734
#
# /opt/conda/lib/python3.9/site-packages/numpy/lib/function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3849                         interpolation='linear', keepdims=False):
#    3850     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 3851     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3852                     overwrite_input=overwrite_input,
#    3853                     interpolation=interpolation)
#
# /opt/conda/lib/python3.9/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3427         keepdim = (1,) * a.ndim
#    3428
# -> 3429     r = func(a, **kwargs)
#    3430     return r, keepdim
#    3431
#
# /opt/conda/lib/python3.9/site-packages/numpy/lib/function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3952         weights_above.shape = weights_shape
#    3953
# -> 3954         ap.partition(concatenate((indices_below, indices_above)), axis=axis)
#    3955
#    3956         # ensure axis with q-th is first
#
# TypeError: '<' not supported between instances of 'Timestamp' and 'str'

# %%
joined_oo.quantile(q=0.75)
# Out:
# RATE_USD                             3870.0000
# SELF_SERVE                              0.0000
# IS_OFFER_APPROVED                       1.0000
# AUTOMATICALLY_APPROVED                  0.0000
# MANUALLY_APPROVED                       1.0000
# WAS_EVER_UNCOVERED                      0.0000
# COVERING_OFFER                          1.0000
# LOAD_DELIVERED_FROM_OFFER               1.0000
# RECOMMENDED_LOAD                        0.0000
# VALID                                   1.0000
# APPROXIMATE_DRIVING_ROUTE_MILEAGE    1328.0000
# PALLETIZED_LINEAR_FEET                 52.0000
# FD_ENABLED                              1.0000
# EXCLUSIVE_USE_REQUESTED                 0.0000
# HAZARDOUS                               0.0000
# REEFER_ALLOWED                          1.0000
# STRAIGHT_TRUCK_ALLOWED                  1.0000
# LOAD_BAR_COUNT                          0.0000
# LOAD_TO_RIDE_REQUESTED                  1.0000
# ESTIMATED_COST_AT_ORDER              3741.9288
# Name: 0.75, dtype: float64

# %%
train=joinedDF.sample(frac=0.8,random_state=200)
test=joinedDF.drop(train.index)

# %%
bool_column_names + numerical_loggable_column_names
# Out:
# ['FD_ENABLED',
#  'EXCLUSIVE_USE_REQUESTED',
#  'HAZARDOUS',
#  'REEFER_ALLOWED',
#  'STRAIGHT_TRUCK_ALLOWED',
#  'LOAD_TO_RIDE_REQUESTED',
#  'APPROXIMATE_DRIVING_ROUTE_MILEAGE',
#  'PALLETIZED_LINEAR_FEET',
#  'SECONDS_BETWEEN_ORDER_AND_DEADLINE',
#  'LOAD_BAR_COUNT',
#  'ESTIMATED_COST_AT_ORDER']

# %%
xTrain = train[bool_column_names + numerical_loggable_column_names].to_numpy()
yTrain = train['NUMBER_OFFERS'].to_numpy()
xTest = test[bool_column_names + numerical_loggable_column_names].to_numpy()
yTest = test['NUMBER_OFFERS'].to_numpy()

# %%
reg = LinearRegression().fit(xTrain, yTrain)
preds = reg.predict(xTest).round()
mean_absolute_error(yTest,preds)
# Out:
# 2.1593948144892963

# %%
pd.Series(preds).value_counts()
# Out:
# 3.0    11115
# 4.0     2768
# 2.0     1923
# 1.0       85
# 5.0       38
# dtype: int64

# %%
avg_pred = [np.mean(nOffers_rec)] * len(yTest)
mean_absolute_error(yTest,avg_pred)
# Out:
# 2.3643080876431477

# %%
np.bincount(yTest.astype(int))
# Out:
# array([2455, 3510, 2797, 2043, 1446, 1029,  734,  541,  367,  274,  219,
#         179,  147,  105,   83])

# %%
np.bincount(preds.astype(int))
# Out:
# array([    0,    85,  1923, 11115,  2768,    38])

# %%
np.unique(preds.astype(int))
# Out:
# array([1, 2, 3, 4, 5])

# %%
offers.index
# Out:
# RangeIndex(start=0, stop=707418, step=1)

# %%
joinedTable = test.join(offers.set_index('REFERENCE_NUMBER'),how = 'inner')

# %%
joinedTable
# Out:
#                                                     ORDER_DATETIME_PST  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-16 12:44:16
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-16 12:44:16
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-16 12:44:16
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222... 2020-08-17 15:29:20
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225... 2022-02-24 09:07:45
# ...                                                                ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60... 2022-08-22 07:52:21
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-29 15:39:19
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-29 15:39:19
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-29 15:39:19
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-29 15:39:19
#
#                                                    PICKUP_DEADLINE_PST  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-24 13:00:00
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-24 13:00:00
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-24 13:00:00
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222... 2020-08-18 15:30:00
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225... 2022-02-28 14:00:00
# ...                                                                ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60... 2022-08-30 11:00:00
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-31 11:00:00
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-31 11:00:00
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-31 11:00:00
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-31 11:00:00
#
#                                                    DELIVERY_TIME_CONSTRAINT  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                 SCHEDULE
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                 SCHEDULE
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                 SCHEDULE
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                     NONE
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                     NONE
# ...                                                                     ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                 SCHEDULE
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                 SCHEDULE
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                 SCHEDULE
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                 SCHEDULE
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                 SCHEDULE
#
#                                                    ORIGIN_3DIGIT_ZIP  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...               281
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...               281
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...               281
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...               900
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...               716
# ...                                                              ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...               305
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               303
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               303
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               303
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               303
#
#                                                    DESTINATION_3DIGIT_ZIP  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    750
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    750
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    750
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                    276
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                    515
# ...                                                                   ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                    720
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    945
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    945
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    945
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    945
#
#                                                     APPROXIMATE_DRIVING_ROUTE_MILEAGE  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                             1061.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                             1061.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                             1061.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                             2547.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                              611.0
# ...                                                                               ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                              606.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                             2471.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                             2471.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                             2471.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                             2471.0
#
#                                                     PALLETIZED_LINEAR_FEET  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    22.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    22.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    22.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                    24.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                    52.0
# ...                                                                    ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                    53.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    47.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    47.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    47.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    47.0
#
#                                                     FD_ENABLED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...        True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...        True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...        True
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...        True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...        True
# ...                                                        ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...        True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...        True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...        True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...        True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...        True
#
#                                                     EXCLUSIVE_USE_REQUESTED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                     True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                     True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                     True
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                     True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                     True
# ...                                                                     ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                    False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                     True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                     True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                     True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                     True
#
#                                                     HAZARDOUS  REEFER_ALLOWED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...      False           False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...      False           False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...      False           False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...      False            True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...      False           False
# ...                                                       ...             ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...      False            True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...      False            True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...      False            True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...      False            True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...      False            True
#
#                                                     STRAIGHT_TRUCK_ALLOWED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                   False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                   False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                   False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                    True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                   False
# ...                                                                    ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                    True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                   False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                   False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                   False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                   False
#
#                                                     LOAD_BAR_COUNT  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...             0.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...             0.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...             0.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...             0.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...             0.0
# ...                                                            ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...             0.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             0.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             0.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             0.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             0.0
#
#                                                     LOAD_TO_RIDE_REQUESTED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    True
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                   False
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                   False
# ...                                                                    ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                   False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    True
#
#                                                     ESTIMATED_COST_AT_ORDER  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                3024.8049
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                3024.8049
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                3024.8049
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                9245.7654
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                2956.8993
# ...                                                                     ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                1829.2716
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                6936.4461
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                6936.4461
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                6936.4461
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                6936.4461
#
#                                                     ... NUMBER_OFFERS  \
# REFERENCE_NUMBER                                    ...
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...  ...           3.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...  ...           3.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...  ...           3.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...  ...           1.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...  ...           1.0
# ...                                                 ...           ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...  ...           4.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...  ...           4.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...  ...           4.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...  ...           4.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...  ...           4.0
#
#                                                    SECONDS_BETWEEN_ORDER_AND_DEADLINE  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                           692144.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                           692144.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                           692144.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                            86440.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                           363135.0
# ...                                                                               ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                           702459.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                           156041.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                           156041.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                           156041.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                           156041.0
#
#                                                                                            CARRIER_ID  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...  d5b925f7508544b836a758dfd0c5a6fb316694cee8be82...
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...  ccf51d90eb2019002bd4b6f104a5c4dec9aa4fc2fb3672...
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...  d5b925f7508544b836a758dfd0c5a6fb316694cee8be82...
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...  c25ed90a126cbdabb004b777139973b0652f84051907c8...
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...  62fcdb6ab7d866469212eb68cea38fd06fa6c92dc597ad...
# ...                                                                                               ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...  a4f3530830cabf2d9e40d2971ea6a17e38535e764bccc3...
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...  742a443c030dc6f372319158da396c1005b2930fcc943e...
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...  7ca2552ffd0e38deee9b22af6d3e8ce9fe88ec88162469...
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...  b910260d6ccd1fedb9919e9974c4b1eacf7ff1e3a4643c...
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...  b910260d6ccd1fedb9919e9974c4b1eacf7ff1e3a4643c...
#
#                                                          CREATED_ON_HQ  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-20 11:48:15
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-20 07:59:23
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-20 07:59:38
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222... 2020-08-17 15:47:22
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225... 2022-02-25 12:03:57
# ...                                                                ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60... 2022-08-26 08:38:59
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-30 09:17:41
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-30 07:35:52
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-30 06:16:49
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-30 06:14:54
#
#                                                    RATE_USD OFFER_TYPE  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...   3096.0      quote
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...   3096.0      quote
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...   3096.0      quote
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...   9288.0      quote
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...   2709.0      quote
# ...                                                     ...        ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...   2128.5      quote
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...   6450.0      quote
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...   6708.0      quote
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...   6708.0      quote
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...   6708.0      quote
#
#                                                     SELF_SERVE  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...       False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...       False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...       False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...       False
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...       False
# ...                                                        ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...        True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...       False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...       False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...       False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...       False
#
#                                                    IS_OFFER_APPROVED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...              True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...             False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...             False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...             False
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...              True
# ...                                                              ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...             False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...              True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             False
#
#                                                     AUTOMATICALLY_APPROVED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                   False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                   False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                   False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                   False
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                    True
# ...                                                                    ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                   False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                   False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                   False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                   False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                   False
#
#                                                     MANUALLY_APPROVED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...               True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...              False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...              False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...              False
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...              False
# ...                                                               ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...              False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...              False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...              False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...              False
#
#                                                     WAS_EVER_UNCOVERED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...               False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...               False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...               False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...               False
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...               False
# ...                                                                ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...               False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               False
#
#                                                     COVERING_OFFER  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...            True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...           False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...           False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...            True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...            True
# ...                                                            ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...           False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...            True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...           False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...           False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...           False
#
#                                                     LOAD_DELIVERED_FROM_OFFER  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                       True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                      False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                      False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                       True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                       True
# ...                                                                       ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                      False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                       True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                      False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                      False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                      False
#
#                                                     RECOMMENDED_LOAD  VALID
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...             False   True
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...             False  False
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...             False   True
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...             False   True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...             False   True
# ...                                                              ...    ...
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...              True   True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             False   True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             False   True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             False   True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             False   True
#
# [54245 rows x 32 columns]

# %%
uniqueRefs = joinedTable.index.unique()[:500]

# %%
#joinedTable['OFF_TO_ACCEPT'] = joined

# %%
test = test.reset_index()

# %%
accepted_offer = []
for i in uniqueRefs:
    best_calc = int(test.where(test['REFERENCE_NUMBER'] == i).dropna()['Estimated_Num_offers']/np.e)
    offers_at_ref = list(offers.where(offers['REFERENCE_NUMBER'] == i).dropna())
    accepted_offer.append((str(i), offers_at_ref[best_calc-1]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Estimated_Num_offers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_101/2050264134.py in <module>
#       1 accepted_offer = []
#       2 for i in uniqueRefs:
# ----> 3     best_calc = int(test.where(test['REFERENCE_NUMBER'] == i).dropna()['Estimated_Num_offers']/np.e)
#       4     offers_at_ref = list(offers.where(offers['REFERENCE_NUMBER'] == i).dropna())
#       5     accepted_offer.append((str(i), offers_at_ref[best_calc-1]))
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Estimated_Num_offers'

# %%
offers_at_ref
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_101/1003070413.py in <module>
# ----> 1 offers_at_ref
#
# NameError: name 'offers_at_ref' is not defined

# %%
offers = offers.reset_index().sort_values(by = ['REFERENCE_NUMBER', 'CREATED_ON_HQ'], na_position = 'first')

# %%
test['Estimated_Num_offers'] = preds.astype(int)
test
# Out:
#                                                     ORDER_DATETIME_PST  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-16 12:44:16
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222... 2020-08-17 15:29:20
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225... 2022-02-24 09:07:45
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0... 2022-08-22 08:36:55
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901... 2021-09-30 06:29:59
# ...                                                                ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292... 2021-11-22 14:02:31
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf... 2022-09-16 13:55:55
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371... 2022-08-15 10:50:30
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60... 2022-08-22 07:52:21
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-29 15:39:19
#
#                                                    PICKUP_DEADLINE_PST  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d... 2022-06-24 13:00:00
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222... 2020-08-18 15:30:00
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225... 2022-02-28 14:00:00
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0... 2022-09-07 13:00:00
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901... 2021-10-05 07:00:00
# ...                                                                ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292... 2021-11-29 13:00:00
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf... 2022-09-20 15:00:00
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371... 2022-08-16 12:00:00
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60... 2022-08-30 11:00:00
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b... 2021-03-31 11:00:00
#
#                                                    DELIVERY_TIME_CONSTRAINT  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                 SCHEDULE
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                     NONE
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                     NONE
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                 SCHEDULE
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                 SCHEDULE
# ...                                                                     ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                 SCHEDULE
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                 SCHEDULE
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                 SCHEDULE
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                 SCHEDULE
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                 SCHEDULE
#
#                                                    ORIGIN_3DIGIT_ZIP  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...               281
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...               900
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...               716
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...               305
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...               296
# ...                                                              ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...               303
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...               841
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...               303
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...               305
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...               303
#
#                                                    DESTINATION_3DIGIT_ZIP  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    750
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                    276
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                    515
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                    704
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                    281
# ...                                                                   ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                    282
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                    604
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                    296
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                    720
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    945
#
#                                                     APPROXIMATE_DRIVING_ROUTE_MILEAGE  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                             1061.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                             2547.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                              611.0
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                              503.0
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                              139.0
# ...                                                                               ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                              256.0
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                             1397.0
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                              166.0
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                              606.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                             2471.0
#
#                                                     PALLETIZED_LINEAR_FEET  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    22.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                    24.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                    52.0
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                    52.0
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                    46.0
# ...                                                                    ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                   100.0
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                   100.0
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                    48.0
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                    53.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    47.0
#
#                                                     FD_ENABLED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...        True
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...        True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...        True
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...        True
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...        True
# ...                                                        ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...        True
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...        True
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...        True
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...        True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...        True
#
#                                                     EXCLUSIVE_USE_REQUESTED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                     True
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                     True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                     True
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                    False
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                    False
# ...                                                                     ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                     True
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                     True
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                     True
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                    False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                     True
#
#                                                     HAZARDOUS  REEFER_ALLOWED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...      False           False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...      False            True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...      False           False
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...      False            True
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...      False            True
# ...                                                       ...             ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...      False            True
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...      False           False
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...      False           False
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...      False            True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...      False            True
#
#                                                     STRAIGHT_TRUCK_ALLOWED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                   False
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                    True
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                   False
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                    True
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                    True
# ...                                                                    ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                    True
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                   False
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                   False
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                    True
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                   False
#
#                                                     LOAD_BAR_COUNT  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...             0.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...             0.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...             0.0
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...             0.0
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...             0.0
# ...                                                            ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...             0.0
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...             0.0
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...             0.0
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...             0.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...             0.0
#
#                                                     LOAD_TO_RIDE_REQUESTED  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                    True
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                   False
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                   False
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                   False
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                   False
# ...                                                                    ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                    True
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                    True
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                    True
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                   False
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                    True
#
#                                                     ESTIMATED_COST_AT_ORDER  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                3024.8049
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                9245.7654
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                2956.8993
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                1641.6411
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                 896.8596
# ...                                                                     ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                1411.5309
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                3099.6636
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                 965.5263
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                1829.2716
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                6936.4461
#
#                                                    TRANSPORT_MODE  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...            FTL
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...            FTL
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...            FTL
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...            FTL
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...            FTL
# ...                                                           ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...            FTL
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...            FTL
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...            FTL
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...            FTL
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...            FTL
#
#                                                    Time_between_Order_pickup  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...           8 days 00:15:44
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...           1 days 00:00:40
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...           4 days 04:52:15
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...          16 days 04:23:05
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...           5 days 00:30:01
# ...                                                                      ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...           6 days 22:57:29
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...           4 days 01:04:05
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...           1 days 01:09:30
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...           8 days 03:07:39
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...           1 days 19:20:41
#
#                                                     NUMBER_OFFERS  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...            3.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...            1.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...            1.0
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...            0.0
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...            2.0
# ...                                                           ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...            0.0
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...            0.0
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...            3.0
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...            4.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...            4.0
#
#                                                     SECONDS_BETWEEN_ORDER_AND_DEADLINE  \
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                            692144.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                             86440.0
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                            363135.0
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                           1398185.0
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                            433801.0
# ...                                                                                ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                            601049.0
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                            349445.0
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                             90570.0
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                            702459.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                            156041.0
#
#                                                     Estimated_Num_offers
# REFERENCE_NUMBER
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d...                     4
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa222...                     3
# [\n  "000880c3b32626141c08b5040c79d5bdb72af4225...                     3
# [\n  "000d3a9bad1e2fa2c921b7565f21f5d31fe9291f0...                     3
# [\n  "0011ec19bd38340c2a86d26fee984485ed966a901...                     3
# ...                                                                  ...
# [\n  "ffe54c86ce7ef7be88217ab660f339c45e46e1292...                     2
# [\n  "ffef1a34842ba031f5fbf07203651a9116a447edf...                     3
# [\n  "fff53791fdea029938fbbc7f613aaf68505f95371...                     3
# [\n  "fff6f947ed25527c7ac3e4c2e598bbfaa17fa4f60...                     3
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b...                     3
#
# [15929 rows x 20 columns]

# %% [markdown]
# # FTL

# %%
ftl = orders[orders['TRANSPORT_MODE'] == 'FTL']
ftl.set_index('REFERENCE_NUMBER',inplace = True)
offers.set_index('REFERENCE_NUMBER',inplace = True)

# %%
joinedDF = ftl.join(offers,how = 'left')
joinedDF.head()
# Out:
#                                                     ORDER_DATETIME_PST  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-18 12:45:34
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-18 12:45:34
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-18 12:45:34
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-18 12:45:34
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-18 12:45:34
#
#                                                    PICKUP_DEADLINE_PST  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-24 11:00:00
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-24 11:00:00
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-24 11:00:00
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-24 11:00:00
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-24 11:00:00
#
#                                                    DELIVERY_TIME_CONSTRAINT  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 SCHEDULE
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 SCHEDULE
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 SCHEDULE
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 SCHEDULE
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 SCHEDULE
#
#                                                    ORIGIN_3DIGIT_ZIP  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...               761
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...               761
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...               761
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...               761
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...               761
#
#                                                    DESTINATION_3DIGIT_ZIP  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    304
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    304
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    304
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    304
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    304
#
#                                                     APPROXIMATE_DRIVING_ROUTE_MILEAGE  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                             1025.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                             1025.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                             1025.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                             1025.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                             1025.0
#
#                                                     PALLETIZED_LINEAR_FEET  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    52.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    52.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    52.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    52.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    52.0
#
#                                                     FD_ENABLED  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...        True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...        True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...        True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...        True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...        True
#
#                                                     EXCLUSIVE_USE_REQUESTED  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                     True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                     True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                     True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                     True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                     True
#
#                                                     HAZARDOUS  REEFER_ALLOWED  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...      False           False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...      False           False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...      False           False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...      False           False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...      False           False
#
#                                                     STRAIGHT_TRUCK_ALLOWED  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                   False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                   False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                   False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                   False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                   False
#
#                                                     LOAD_BAR_COUNT  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             0.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             0.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             0.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             0.0
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             0.0
#
#                                                     LOAD_TO_RIDE_REQUESTED  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                    True
#
#                                                     ESTIMATED_COST_AT_ORDER  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 2353.605
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 2353.605
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 2353.605
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 2353.605
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                 2353.605
#
#                                                    TRANSPORT_MODE  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...            FTL
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...            FTL
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...            FTL
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...            FTL
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...            FTL
#
#                                                    Time_between_Order_pickup  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...           5 days 22:14:26
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...           5 days 22:14:26
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...           5 days 22:14:26
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...           5 days 22:14:26
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...           5 days 22:14:26
#
#                                                                                            CARRIER_ID  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...  23cdd018d515d5e59464aa65d8eb5b781e3a4872e18aa2...
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...  f91b043302878951ce9258214033bd206ea0a92bb88931...
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...  6326cfe26285d0f687c2cc5385aad8a0f7b2664a30c84a...
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...  2fe98face8187bcd9a099889cbb3d02c4a80b9fc72ec9f...
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...  f91b043302878951ce9258214033bd206ea0a92bb88931...
#
#                                                          CREATED_ON_HQ  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-24 07:12:40
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-23 10:55:30
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-23 10:18:47
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-24 05:14:46
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f... 2022-08-23 10:57:27
#
#                                                     RATE_USD OFFER_TYPE  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...    2967.0      quote
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...    3483.0      quote
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...    3483.0      quote
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...    3225.0      quote
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...    3483.0      quote
#
#                                                    SELF_SERVE  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...      False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...      False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...      False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...       True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...       True
#
#                                                    IS_OFFER_APPROVED  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...              True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             False
#
#                                                    AUTOMATICALLY_APPROVED  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                  False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                  False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                  False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                  False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                  False
#
#                                                    MANUALLY_APPROVED  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...              True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             False
#
#                                                    WAS_EVER_UNCOVERED  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...              False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...              False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...              False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...              False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...              False
#
#                                                    COVERING_OFFER  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...           True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...          False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...          False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...          False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...          False
#
#                                                    LOAD_DELIVERED_FROM_OFFER  \
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                      True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                     False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                     False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                     False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...                     False
#
#                                                    RECOMMENDED_LOAD  VALID
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...            False   True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...            False  False
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...            False   True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...             True   True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872f...            False   True

# %% [markdown]
# ## Do Orders get 0 offers

# %%
off = offers.index.to_list()
z = joinedDF[joinedDF['VALID'].isnull()].index.to_list()[:100]
orde =orders['REFERENCE_NUMBER'].to_list()
numOff = 0
numOrd = 0
for i in z:
    if i in off:
        numOff +=1
    if i in orde:
        numOrd +=1
numOff,numOrd
# Out:
# (0, 100)

# %% [markdown]
# ### yes orders get 0 offers, about 10919 orders without offer.

# %%
# create new column whether order recieved offer
joinedDF['Recieved_Offer'] = joinedDF.notnull()['VALID']
joinedDF['Recieved_Offer']
# Out:
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872ff0045411bca69345c97c70c"\n]     True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872ff0045411bca69345c97c70c"\n]     True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872ff0045411bca69345c97c70c"\n]     True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872ff0045411bca69345c97c70c"\n]     True
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872ff0045411bca69345c97c70c"\n]     True
#                                                                               ...
# [\n  "fffed2af60b0061cbe9423f48735baff489a073f3a7bb46606c0cf623bf7d5bc"\n]    False
# [\n  "ffff4267ee0ce72d72a1ca2cf36af423d7d61405aac57a4b03df8b7ae4dba3ee"\n]     True
# [\n  "ffff4267ee0ce72d72a1ca2cf36af423d7d61405aac57a4b03df8b7ae4dba3ee"\n]     True
# [\n  "ffff4267ee0ce72d72a1ca2cf36af423d7d61405aac57a4b03df8b7ae4dba3ee"\n]     True
# [\n  "ffff4267ee0ce72d72a1ca2cf36af423d7d61405aac57a4b03df8b7ae4dba3ee"\n]     True
# Name: Recieved_Offer, Length: 280273, dtype: bool

# %% [markdown]
# # Results of Flock Method vs Best possible

# %%
# removing Uncovered
orderWoffer = joinedDF[joinedDF['Recieved_Offer']]
orderWoffer.reset_index(inplace = True)
cover = orderWoffer.drop(orderWoffer[orderWoffer['WAS_EVER_UNCOVERED']].index)

# %%
indexIn = cover.set_index('REFERENCE_NUMBER')
flockAccept = indexIn[indexIn['LOAD_DELIVERED_FROM_OFFER']].RATE_USD
flockN = len(flockAccept)
flockT = sum(flockAccept)
flockM = np.mean(flockAccept)
print('Number of Orders Fulfilled: ' + str(flockN))
print('Total Contract Value: ' + str(flockT))
print('Mean Contract Value: ' + str(flockM))
# Out:
# Number of Orders Fulfilled: 62103
# Total Contract Value: 209625472.59150046
# Mean Contract Value: 3375.448409762821

# %%
bestAccept = cover.groupby('REFERENCE_NUMBER')['RATE_USD'].min()
bestN = len(bestAccept)
bestT = sum(bestAccept)
bestM = np.mean(bestAccept)

print('Number of Orders Fulfilled: ' + str(bestN))
print('Total Contract Value: ' + str(bestT))
print('Mean Contract Value: ' + str(bestM))
# Out:
# Number of Orders Fulfilled: 68222
# Total Contract Value: 226338405.93270046
# Mean Contract Value: 3317.674737367718

# %%
print('Flock Missed: ' + str(bestN-flockN))
print('Extra Spent: ' + str(bestT-flockT))
print('Mean Contract Value: ' + str(bestM-flockM))
# Out:
# Flock Missed: 6119
# Extra Spent: 16712933.341199994
# Mean Contract Value: -57.77367239510295

# %%
# how flock could have done with offer
tf = cover.groupby('REFERENCE_NUMBER')['LOAD_DELIVERED_FROM_OFFER'].apply(any)
pot = bestAccept[tf]
bestN = len(pot)
bestT = sum(pot)
bestM = np.mean(pot)

print('Number of Orders Fulfilled: ' + str(bestN))
print('Total Contract Value: ' + str(bestT))
print('Mean Contract Value: ' + str(bestM))
# Out:
# Number of Orders Fulfilled: 62103
# Total Contract Value: 204460973.00700065
# Mean Contract Value: 3292.2881826481917

# %%
print('Flock Missed: ' + str(bestN-flockN))
print('Extra Spent: ' + str(bestT-flockT))
print('Mean Contract Value: ' + str(bestM-flockM))
# Out:
# Flock Missed: 0
# Extra Spent: -5164499.584499806
# Mean Contract Value: -83.16022711462938

# %% [markdown]
# # Summary of Analysis FTL
#
# #### Flock missed out on 6119 contracts by not accepting anything
# #### Flock could have saved 58 dollars on average if getting the best offer everytime while doing the extra 6119
# #### Flock could have saved 83 dollars on average if getting the best offer on the ones they offered
# #### Flock Picked 12,413 wrong and 7 cost them over 10,000 dollars each

# %% [markdown]
# # How well did the estimate offer do

# %%
estimate = cover.groupby('REFERENCE_NUMBER')['ESTIMATED_COST_AT_ORDER'].mean()

# %%
estimate
# Out:
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872ff0045411bca69345c97c70c"\n]    2353.6050
# [\n  "0002e80902489c5a5eed029971f32e2ade3513870d804c653e8fcb3523a431aa"\n]    5243.3082
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d87a5e49200bbb8a14643371"\n]    3024.8049
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa2220f6b340d550c952ea4caf23"\n]    9245.7654
# [\n  "0004ef769b6e6e2a753c030ba14bfb33c88e392cf70a3acbdd840a5bda2f4fd0"\n]     835.7394
#                                                                                 ...
# [\n  "fffb240d62d732bd179440f15272283f408368ed1595415e5498d3457eafc659"\n]    7384.5534
# [\n  "fffbec3e1ffcf0c505877a2b68e8fc773a413f9db25cc40fb66eff17b333354a"\n]    9373.3464
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b440027ee7dc899a4f59b107"\n]    6936.4461
# [\n  "fffdb6cd77e2d5e8bfa5a355cf80a2c90a1a800f086add7b12f7d0ae1e2ecdca"\n]    2848.8618
# [\n  "ffff4267ee0ce72d72a1ca2cf36af423d7d61405aac57a4b03df8b7ae4dba3ee"\n]    2565.2682
# Name: ESTIMATED_COST_AT_ORDER, Length: 68222, dtype: float64

# %%
bestAccept
# Out:
# REFERENCE_NUMBER
# [\n  "000020adb97f32cf89e5f094b35607499f7ff872ff0045411bca69345c97c70c"\n]    2967.0
# [\n  "0002e80902489c5a5eed029971f32e2ade3513870d804c653e8fcb3523a431aa"\n]    5160.0
# [\n  "0003d127b27fd50722f3e43a6e3b19562ed5a176d87a5e49200bbb8a14643371"\n]    3096.0
# [\n  "0004b681b1c4f14dc289a36cf0590ffce5b6aa2220f6b340d550c952ea4caf23"\n]    9288.0
# [\n  "0004ef769b6e6e2a753c030ba14bfb33c88e392cf70a3acbdd840a5bda2f4fd0"\n]     774.0
#                                                                                ...
# [\n  "fffb240d62d732bd179440f15272283f408368ed1595415e5498d3457eafc659"\n]    7740.0
# [\n  "fffbec3e1ffcf0c505877a2b68e8fc773a413f9db25cc40fb66eff17b333354a"\n]    9417.0
# [\n  "fffc15629ba0aa26f5252d1b619e01cf10306f97b440027ee7dc899a4f59b107"\n]    6450.0
# [\n  "fffdb6cd77e2d5e8bfa5a355cf80a2c90a1a800f086add7b12f7d0ae1e2ecdca"\n]    2838.0
# [\n  "ffff4267ee0ce72d72a1ca2cf36af423d7d61405aac57a4b03df8b7ae4dba3ee"\n]    2451.0
# Name: RATE_USD, Length: 68222, dtype: float64

# %%
frame = { 'Estimate': estimate, 'Accepted': flockAccept,'Best': bestAccept}
#Creating DataFrame by passing Dictionary
result = pd.DataFrame(frame)

# %%
result['estVSbest'] = np.abs(result['Estimate'] - result['Best'])
result['estVSreal'] = np.abs(result['Estimate'] - result['Accepted'])
np.mean(result)
# Out:
# /opt/conda/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3370: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Estimate     3388.905234
# Accepted     3375.448410
# Best         3317.674737
# estVSbest     331.680834
# estVSreal     334.940814
# dtype: float64

# %%
result.mean()
# Out:
# Estimate     3388.905234
# Accepted     3375.448410
# Best         3317.674737
# estVSbest     331.680834
# estVSreal     334.940814
# dtype: float64

# %%
sum(result['estVSreal'] > 0)
# Out:
# 61867

# %%
sum(result['estVSreal'] < 0)
# Out:
# 0

# %% [markdown]
# # PTL

# %%
ptl = orders[orders['TRANSPORT_MODE'] == 'PTL']
ptl.groupby('REFERENCE_NUMBER').count()['ORDER_DATETIME_PST'].sort_values()
# Out:
# REFERENCE_NUMBER
# [\n  "00003e8484fe610f9a8040b7ab5cc4593c50186a1efd30d61cb6a49109484486"\n]    1
# [\n  "aa0a913da9877658e4ec3a932facccb51d3fd29841d51d9bd2392e0eaeeb2271"\n]    1
# [\n  "aa0a4345921cefee0219a66125fe28287ce6c0023610510126442a902d1c2ee5"\n]    1
# [\n  "aa0a0be39d7ec1dabc1625ac697a9e2e4985f17515509594a0db458354cf4e21"\n]    1
# [\n  "aa096a892fe2c009fdf0374f0564444eac6322809063cf5d41791440ec1a455c"\n]    1
#                                                                              ..
# [\n  "674033cf6c9aa8fe0550c49c3ea22ace85857cdb71f8f899add66d9752377772"\n]    4
# [\n  "de513fbf2547a8a1194f5f3233c902dd73605274aee0aeda673c137ad864457e"\n]    4
# [\n  "b12e3ee65eb2bfdec4c36e28da67cde3d61c1d56d2d8a124f147bdd222cd7001"\n]    4
# [\n  "66ac2263dd12859e37491bf72efbad9fe696f9cd13b67b261dd1effd0b2686b6"\n]    4
# [\n  "7689dfa37fa7621c67e911b0b72d8b2339ef4810647f30685ae8da9e0cbe5793"\n]    4
# Name: ORDER_DATETIME_PST, Length: 134724, dtype: int64
